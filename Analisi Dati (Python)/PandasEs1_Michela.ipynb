# %%
import pandas as pd
import numpy as np

# %%
pd.read_excel("Pandas/coalpublic2013.xls")
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1445  2013  1103254                   Fidelity Mine  Refuse Recovery
# 1446  2013  1102636                             Wfi  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
# 1448  2013  1518524               Turkey Pen Refuse  Refuse Recovery
# 1449  2013  1519685           Fedscreek Refuse Pile  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# 0           Bibb  Active, men working, not producing      Surface
# ...

# %%
df = pd.read_excel("Pandas/coalpublic2013.xls")

# %%
#Calcolo la somma della colonna "Production (short tons)"
sums = df["Production (short tons)"].sum()
print("Sum of values of Production-column:")
print(sums)
# Out:
# Sum of values of Production-column:
# 984841779

# %%
#Calcolo la media della colonna "Production (short tons)"
media = df["Production (short tons)"].mean()
print("Mean of column Production:")
print(media)
# Out:
# Mean of column Production:
# 679201.2268965517

# %%
#Calcolo il valore massimo e minimo della colonna "Production (short tons)"
max = df["Production (short tons)"].max()

min = df["Production (short tons)"].min()

print("Min of column Production:")
print(min)
print("Max of column Production:")
print(max)
# Out:
# Min of column Production:
# 0
# Max of column Production:
# 111005549
